# %%
import pandas as pd
import os
import json

# %%
from tasks.download import download_data

# %%
download_data(fresh_start=False)

# %%
from tasks.preprocess import process_APIs_raw_data

# %%
process_APIs_raw_data()
# Out:
# PreProcessing data/indicator/GV1/raw/GV1_WB.json: ['']
# DONE
# PreProcessing data/indicator/EE2/raw/EE2_SDG.json: []
# DONE
# PreProcessing data/indicator/EE2/raw/EE2_WB.json: ['']
# DONE
# PreProcessing data/indicator/SE2/raw/SE2.2_SDG.json: []
# DONE
# PreProcessing data/indicator/SE2/raw/SE2.4_WB.json: ['']
# DONE
# PreProcessing data/indicator/SE2/raw/SE2.1_WB.json: []
# DONE
# PreProcessing data/indicator/SE2/raw/SE2.2_WB.json: ['']
# DONE
# PreProcessing data/indicator/SE2/raw/SE2.3_SDG.json: []
# DONE
# PreProcessing data/indicator/SE2/raw/SE2.4_SDG.json: []
# DONE
# PreProcessing data/indicator/SE2/raw/SE2.0_SDG.json: []
# DONE
# PreProcessing data/indicator/SE2/raw/SE2.5_SDG.json: []
# DONE
# PreProcessing data/indicator/SE2/raw/SE2.1_SDG.json: []
# DONE
# PreProcessing data/indicator/SE2/raw/SE2.5_WB.json: ['']
# DONE
# PreProcessing data/indicator/SE2/raw/SE2.3_WB.json:
# ---------------------------------------------------------------------------
# ...

# %%
import pandas as pd
df = pd.read_csv('data/indicator/AB1/preprocessed/AB3.0_WB.csv')

# %%
df.shape

# %%
df.dropna().shape[0]

# %%
df[df.ISO.isna()].Country.unique()

# %%
df.dropna(subset=['ISO'])

# %%
df

# %%
indicators = ['GV1', 'EE2', 'SE2', 'CV2', 'ME1', 'BE3', 'ME2',
              'BE2', 'SP1', 'EW1', 'EQ1', 'CV3', 'SE1', 'CV1',
              'GT1', 'SP3', 'SE3', 'GB3', 'GE1', 'GB2', 'GJ1',
              'SP2', 'EW2', 'EE1', 'SL1', 'AB3', 'AB2', 'EQ2',
              'AB1', 'SL2', 'EQ3', 'GB1', 'BE1', 'GE3', 'GE2', 'GN1']


def get_preprocessed_files_from_indicator(indicator):
    files =  os.listdir(f'data/indicator/{indicator}/preprocessed')
    return [(file, indicator) for file in files] 

def get_preprocessed_files(indicators):
    files = [get_preprocessed_files_from_indicator(indicator) for indicator in indicators]
    files= [item for sublist in files for item in sublist]
    return files

# %%
get_preprocessed_files(indicators)

# %%
from tasks.preprocess import preprocess_MANUAL_files

# %%
preprocess_MANUAL_files()

# %%
import os

# %%
[(file) for file in os.listdir('data/indicator')]

# %%
import pytest
@pytest.mark.parametrize("input1, input2, output",[(5,5,10),(3,5,12)])
def test_add(input1, input2, output):
	assert input1+input2 == output,"failed"

# %%
import pandas as pd
df = pd.read_csv('data/indicator/SP1/preprocessed/SP1_SDG.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv('data/indicator/GV1/preprocessed/GV1_WB.csv')

# %%
print(df.shape)

# %%
df.dropna(subset=['ISO'])
