# %%
import pandas as pd
import os
import json

# %%
from tasks.download import download_data

# %%
download_data(fresh_start=False)
# Out:
# Downloading GV1's data:
# GV1_WB.json already there
# DONE
# Downloading EE2's data:
# EE2_SDG.json already there
# EE2_WB.json already there
# DONE
# Downloading SE2's data:
# SE2.0_SDG.json already there
# SE2.1_SDG.json already there
# SE2.2_SDG.json already there
# SE2.3_SDG.json already there
# SE2.4_SDG.json already there
# SE2.5_SDG.json already there
# SE2.0_WB.json already there
# SE2.1_WB.json already there
# SE2.2_WB.json already there
# SE2.3_WB.json already there
# SE2.4_WB.json already there
# SE2.5_WB.json already there
# DONE
# Downloading CV2's data:
# DONE
# Downloading ME1's data:
# DONE
# Downloading BE3's data:
# BE3_SDG.json already there
# DONE
# Downloading __pycache__'s data:
# [Errno 2] No such file or directory: 'data/indicator/__pycache__/download_config.json'
# Downloading ME2's data:
# DONE
# Downloading BE2's data:
# BE2_SDG.json already there
# BE2_WB.json already there
# DONE
# Downloading SP1's data:
# SP1_SDG.json already there
# DONE
# Downloading EW1's data:
# EW1_SDG.json already there
# DONE
# Downloading EQ1's data:
# EQ1_SDG.json already there
# EQ1_WB.json already there
# DONE
# Downloading CV3's data:
# CV3_WB.json already there
# DONE
# Downloading SE1's data:
# SE1.0_WB.json already there
# SE1.1_WB.json already there
# SE1.2_WB.json already there
# DONE
# Downloading CV1's data:
# CV1_SDG.json already there
# DONE
# Downloading GT1's data:
# DONE
# Downloading SP3's data:
# SP2_SDG.json already there
# DONE
# Downloading SE3's data:
# SE3_SDG.json already there
# DONE
# Downloading GB3's data:
# DONE
# Downloading GE1's data:
# GE1.0_CW.json already there
# GE1.1_WB.json already there
# DONE
# Downloading GB2's data:
# GB2.0_SDG.json already there
# GB2.1_SDG.json already there
# GB2.0_WB.json already there
# GB2.1_WB.json already there
# DONE
# Downloading GJ1's data:
# DONE
# Downloading SP2's data:
# SP2_SDG.json already there
# DONE
# Downloading EW2's data:
# EW2_SDG.json already there
# EW2_WB.json already there
# DONE
# Downloading EE1's data:
# EE1_SDG.json already there
# DONE
# Downloading SL1's data:
# DONE
# Downloading AB3's data:
# AB3.0_SDG.json already there
# AB3.0_WB.json already there
# AB3.1_WB.json already there
# DONE
# Downloading AB2's data:
# AB2.0_SDG.json already there
# AB2.1_SDG.json already there
# AB2.0_WB.json already there
# AB2.1_WB.json already there
# DONE
# Downloading EQ2's data:
# DONE
# Downloading AB1's data:
# AB1.0_SDG.json already there
# AB1.1_SDG.json already there
# AB1.0_WB.json already there
# AB1.1_WB.json already there
# DONE
# Downloading SL2's data:
# DONE
# Downloading EQ3's data:
# DONE
# Downloading GB1's data:
# GB1_SDG.json already there
# GB1_WB.json already there
# DONE
# Downloading BE1's data:
# BE1.0_SDG.json already there
# BE1.1_SDG.json already there
# BE1.2_SDG.json already there
# BE1.3_SDG.json already there
# DONE
# Downloading GE3's data:
# GE3.1_CW.json already there
# GE3.1.a_WB.json already there
# GE3.1.b_WB.json already there
# GE3.0_WB.json already there
# DONE
# Downloading GE2's data:
# GE2.0_CW.json already there
# GE2.1_WB.json already there
# DONE
# Downloading GN1's data:
# DONE

# %%
from tasks.preprocess import preprocess_MANUAL_files

# %%
preprocess_MANUAL_files()
# Out:
# PreProcessing ME2 Manual files: DONE
# PreProcessing SL1 Manual files: DONE
# PreProcessing SL2 Manual files: DONE
# PreProcessing GJ1 Manual files: DONE
# PreProcessing EQ2 Manual files: DONE
# PreProcessing GN1 Manual files: DONE
# PreProcessing SP2 Manual files: DONE
# PreProcessing GT1 Manual files: DONE
# PreProcessing EQ3 Manual files: DONE
# PreProcessing CV2 Manual files: DONE
# PreProcessing GB3 Manual files: DONE
# PreProcessing ME1 Manual files: DONE

# %%
from tasks.preprocess import process_APIs_raw_data

# %%
process_APIs_raw_data()
# Out:
# PreProcessing data/indicator/GV1/raw/GV1_WB.json: DONE
# PreProcessing data/indicator/EE2/raw/EE2_SDG.json: DONE
# PreProcessing data/indicator/EE2/raw/EE2_WB.json: DONE
# PreProcessing data/indicator/SE2/raw/SE2.2_SDG.json: DONE
# PreProcessing data/indicator/SE2/raw/SE2.4_WB.json: DONE
# PreProcessing data/indicator/SE2/raw/SE2.1_WB.json: DONE
# PreProcessing data/indicator/SE2/raw/SE2.2_WB.json: DONE
# PreProcessing data/indicator/SE2/raw/SE2.3_SDG.json: DONE
# PreProcessing data/indicator/SE2/raw/SE2.4_SDG.json: DONE
# PreProcessing data/indicator/SE2/raw/SE2.0_SDG.json: DONE
# PreProcessing data/indicator/SE2/raw/SE2.5_SDG.json: DONE
# PreProcessing data/indicator/SE2/raw/SE2.1_SDG.json: DONE
# PreProcessing data/indicator/SE2/raw/SE2.5_WB.json: DONE
# PreProcessing data/indicator/SE2/raw/SE2.0_WB.json: DONE
# PreProcessing data/indicator/SE2/raw/SE2.3_WB.json: DONE
# PreProcessing data/indicator/BE3/raw/BE3_SDG.json: DONE
# [Errno 2] No such file or directory: 'data/indicator/__pycache__/raw'
# PreProcessing data/indicator/BE2/raw/BE2_WB.json: DONE
# PreProcessing data/indicator/BE2/raw/BE2_SDG.json: DONE
# PreProcessing data/indicator/SP1/raw/SP1_SDG.json: DONE
# PreProcessing data/indicator/EW1/raw/EW1_SDG.json: DONE
# PreProcessing data/indicator/EQ1/raw/EQ1_SDG.json: DONE
# PreProcessing data/indicator/EQ1/raw/EQ1_WB.json: DONE
# PreProcessing data/indicator/CV3/raw/CV3_WB.json: DONE
# PreProcessing data/indicator/SE1/raw/SE1.2_WB.json: DONE
# PreProcessing data/indicator/SE1/raw/SE1.1_WB.json: DONE
# PreProcessing data/indicator/SE1/raw/SE1.0_WB.json: DONE
# PreProcessing data/indicator/CV1/raw/CV1_SDG.json: DONE
# PreProcessing data/indicator/SP3/raw/SP2_SDG.json: DONE
# PreProcessing data/indicator/SE3/raw/SE3_SDG.json: DONE
# PreProcessing data/indicator/GE1/raw/GE1.0_CW.json: DONE
# PreProcessing data/indicator/GE1/raw/GE1.1_WB.json: DONE
# PreProcessing data/indicator/GB2/raw/GB2.1_WB.json: DONE
# PreProcessing data/indicator/GB2/raw/GB2.1_SDG.json: DONE
# PreProcessing data/indicator/GB2/raw/GB2.0_WB.json: DONE
# PreProcessing data/indicator/GB2/raw/GB2.0_SDG.json: DONE
# PreProcessing data/indicator/SP2/raw/SP2_SDG.json: DONE
# PreProcessing data/indicator/EW2/raw/EW2_WB.json: DONE
# PreProcessing data/indicator/EW2/raw/EW2_SDG.json: DONE
# PreProcessing data/indicator/EE1/raw/EE1_SDG.json: DONE
# PreProcessing data/indicator/AB3/raw/AB3.1_WB.json: DONE
# PreProcessing data/indicator/AB3/raw/AB3.0_SDG.json: DONE
# PreProcessing data/indicator/AB3/raw/AB3.0_WB.json: DONE
# PreProcessing data/indicator/AB2/raw/AB2.0_SDG.json: DONE
# PreProcessing data/indicator/AB2/raw/AB2.1_SDG.json: DONE
# PreProcessing data/indicator/AB2/raw/AB2.1_WB.json: DONE
# PreProcessing data/indicator/AB2/raw/AB2.0_WB.json: DONE
# PreProcessing data/indicator/AB1/raw/AB2.0_SDG.json: DONE
# PreProcessing data/indicator/AB1/raw/AB2.1_SDG.json: DONE
# PreProcessing data/indicator/AB1/raw/AB3.1_WB.json: DONE
# PreProcessing data/indicator/AB1/raw/AB1.1_SDG.json: DONE
# PreProcessing data/indicator/AB1/raw/AB2.1_WB.json: DONE
# PreProcessing data/indicator/AB1/raw/AB2.0_WB.json: DONE
# PreProcessing data/indicator/AB1/raw/AB3.0_SDG.json: DONE
# PreProcessing data/indicator/AB1/raw/AB1.0_SDG.json: DONE
# PreProcessing data/indicator/AB1/raw/AB3.0_WB.json: DONE
# PreProcessing data/indicator/AB1/raw/AB1.1_WB.json: DONE
# PreProcessing data/indicator/AB1/raw/AB1.0_WB.json: DONE
# PreProcessing data/indicator/GB1/raw/GB1_WB.json: DONE
# PreProcessing data/indicator/GB1/raw/GB1_SDG.json: DONE
# PreProcessing data/indicator/BE1/raw/BE1.1_SDG.json: DONE
# PreProcessing data/indicator/BE1/raw/BE1.3_SDG.json: DONE
# PreProcessing data/indicator/BE1/raw/BE1.2_SDG.json: DONE
# PreProcessing data/indicator/BE1/raw/BE1.0_SDG.json: DONE
# PreProcessing data/indicator/GE3/raw/GE3.1.a_WB.json: DONE
# PreProcessing data/indicator/GE3/raw/GE3.1_CW.json: DONE
# PreProcessing data/indicator/GE3/raw/GE3.0_WB.json: DONE
# PreProcessing data/indicator/GE3/raw/GE3.1.b_WB.json: DONE
# PreProcessing data/indicator/GE2/raw/GE2.0_CW.json: DONE
# PreProcessing data/indicator/GE2/raw/GE2.1_WB.json: DONE

# %%
from tasks.compute_indicators import compute_indicators

# %%
compute_indicators()
# Out:
# Computing GE3 for GE3.csv: DONE
# Computing GE2 for GE2.csv: DONE
# Computing GE1 for GE1.csv: DONE
# Computing GB2 for GB2_WB.csv: DONE
# Computing GB2 for GB2_SDG.csv: DONE
# Computing BE1 for BE1.csv: DONE
# Computing SE2 for SE2_WB.csv: DONE
# Computing SE2 for SE2_SDG.csv: DONE
# Computing SE1 for SE1.csv: DONE
# Computing AB3 for AB3.csv: DONE
# Computing AB2 for AB2_SDG.csv: DONE
# Computing AB2 for AB2_WB.csv: DONE
# Computing AB1 for AB1_SDG.csv: DONE
# Computing AB1 for AB1_WB.csv: DONE
