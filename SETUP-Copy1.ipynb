# %%
import pandas as pd
import os
import json

# %%
from tasks.download import download_data

# %%
download_data(fresh_start=False)

# %%
from tasks.preprocess import preprocess_MANUAL_files

# %%
preprocess_MANUAL_files()

# %%
from tasks.preprocess import process_APIs_raw_data

# %%
process_APIs_raw_data()

# %%
from tasks.compute_indicators import compute_indicators

# %%
compute_indicators()

# %%
from tasks.process import process_files

# %%
process_files()
# Out:
# Processing GV1_WB.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/GV1/processed/GV1_WB.csv: Done
# Processing EE2_WB.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/EE2/processed/EE2_WB.csv: Done
# Processing EE2_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/EE2/processed/EE2_SDG.csv: Done
# Processing SE2_WB.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/SE2/processed/SE2_WB.csv: Done
# Processing SE2_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/SE2/processed/SE2_SDG.csv: Done
# Processing CV2_origin.M.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/CV2/processed/CV2_origin.M.csv: Done
# Processing ME1_origin.M.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/ME1/processed/ME1_origin.M.csv: Done
# Processing BE3_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/BE3/processed/BE3_SDG.csv: Done
# Processing ME2_origin.M.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/ME2/processed/ME2_origin.M.csv: Done
# Processing BE2_WB.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/BE2/processed/BE2_WB.csv: Done
# Processing BE2_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/BE2/processed/BE2_SDG.csv: Done
# Processing SP1_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/SP1/processed/SP1_SDG.csv: Done
# Processing EW1_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/EW1/processed/EW1_SDG.csv: Done
# Processing EQ1_WB.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/EQ1/processed/EQ1_WB.csv: Done
# Processing EQ1_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/EQ1/processed/EQ1_SDG.csv: Done
# Processing CV3_WB.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/CV3/processed/CV3_WB.csv: Done
# Processing SE1.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/SE1/processed/SE1.csv: Done
# Processing CV1_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/CV1/processed/CV1_SDG.csv: Done
# Processing GT1_origin.M.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/GT1/processed/GT1_origin.M.csv: Done
# Processing SP3_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/SP3/processed/SP3_SDG.csv: Done
# Processing SP2_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/SP3/processed/SP2_SDG.csv: Done
# Processing SE3_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/SE3/processed/SE3_SDG.csv: Done
# Processing GB3_origin.M.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/GB3/processed/GB3_origin.M.csv: Done
# Processing GE1.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/GE1/processed/GE1.csv: Done
# Processing GB2_WB.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/GB2/processed/GB2_WB.csv: Done
# Processing GB2_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/GB2/processed/GB2_SDG.csv: Done
# Processing GJ1_origin.M.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/GJ1/processed/GJ1_origin.M.csv: Done
# Processing SP2_origin.M.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/SP2/processed/SP2_origin.M.csv: Done
# Processing SP2_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/SP2/processed/SP2_SDG.csv: Done
# Processing EW2_WB.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/EW2/processed/EW2_WB.csv: Done
# Processing EW2_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/EW2/processed/EW2_SDG.csv: Done
# Processing EE1_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/EE1/processed/EE1_SDG.csv: Done
# Processing SL1_origin.M.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/SL1/processed/SL1_origin.M.csv: Done
# Processing AB3.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/AB3/processed/AB3.csv: Done
# Processing AB2_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/AB2/processed/AB2_SDG.csv: Done
# Processing AB2_WB.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/AB2/processed/AB2_WB.csv: Done
# Processing EQ2_origin.M.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/EQ2/processed/EQ2_origin.M.csv: Done
# Processing AB1_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/AB1/processed/AB1_SDG.csv: Done
# Processing AB1_WB.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/AB1/processed/AB1_WB.csv: Done
# Processing SL2_origin.M.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/SL2/processed/SL2_origin.M.csv: Done
# Processing EQ3_origin.M.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/EQ3/processed/EQ3_origin.M.csv: Done
# Processing GB1_SDG.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/GB1/processed/GB1_SDG.csv: Done
# Processing GB1_WB.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/GB1/processed/GB1_WB.csv: Done
# Processing BE1.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/BE1/processed/BE1.csv: Done
# Processing GE3.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/GE3/processed/GE3.csv: Done
# Processing GE2.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/GE2/processed/GE2.csv: Done
# Processing GN1_origin.M.csv:
# Imputation:DONE
# Fromatting:Done
# saving at data/indicator/GN1/processed/GN1_origin.M.csv: Done
