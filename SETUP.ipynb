# %%
import pandas as pd
import os
import json

# %%
data = pd.read_csv('data/indicator/GE2/processed/GE2.csv')#.Description.unique()

# %%
(1e-6 * data['Value']).describe()
# Out:
# count    5.921000e+03
# mean     1.441079e-06
# std      3.324619e-06
# min     -7.602456e-06
# 25%      3.580943e-07
# 50%      6.756632e-07
# 75%      1.252059e-06
# max      3.767702e-05
# Name: Value, dtype: float64

# %%
data['Value'].max()
# Out:
# 43.12900628522567

# %%
ST = pd.read_csv('data/sustainable_targets/ST_2020.csv')

# %%
ST
# Out:
#    Unnamed: 0  Number of targets  Relation   Target 1    Target 2
# 0         EE1                  1  negative   1.092000         NaN
# 1         EE2                  1  positive        NaN   51.400000
# 2         EW1                  1  positive        NaN  265.757935
# 3         EW2                  2  negative  25.000000   75.000000
# 4         SL1                  1  positive        NaN  289.338000
# 5         SL2                  1  positive        NaN   11.900000
# 6         ME1                  1  negative   0.169685         NaN
# 7         ME2                  1  negative   5.000000         NaN
# 8         EQ1                  1  negative  10.000000         NaN
# 9         EQ2                  1  negative   0.000000         NaN
# 10        EQ3                  1  negative   0.001753         NaN
# 11        GE1                  1  negative   0.054000         NaN
# 12        GE2                  1  negative   0.001775         NaN
# ...

# %%
with open('data/indicator/GE1/raw/GE1.0_CW.json') as f:
    data = json.load(f)

# %%
data['data']
# Out:
# [{'id': 518198,
#   'iso_code3': 'AFG',
#   'country': 'Afghanistan',
#   'data_source': 'CAIT',
#   'sector': 'Total including LUCF',
#   'gas': 'CO2',
#   'unit': 'MtCO₂e',
#   'emissions': [{'year': 1990, 'value': 2.91},
#    {'year': 1991, 'value': 2.67},
#    {'year': 1992, 'value': 1.38},
#    {'year': 1993, 'value': 1.31},
#    {'year': 1994, 'value': 1.26},
#    {'year': 1995, 'value': 1.21},
#    {'year': 1996, 'value': 1.14},
#    {'year': 1997, 'value': 1.06},
#    {'year': 1998, 'value': 1.0},
#    {'year': 1999, 'value': 0.79},
#    {'year': 2000, 'value': 0.75},
#    {'year': 2001, 'value': 0.79},
#    {'year': 2002, 'value': 1.06},
#    {'year': 2003, 'value': 1.19},
#    {'year': 2004, 'value': 0.94},
#    {'year': 2005, 'value': 1.32},
#    {'year': 2006, 'value': 1.65},
#    {'year': 2007, 'value': 2.26},
#    {'year': 2008, 'value': 4.2},
#    {'year': 2009, 'value': 6.76},
#    {'year': 2010, 'value': 8.45},
#    {'year': 2011, 'value': 12.23},
# ...
