# %%
import os 
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %%
import os
import pandas as pd
from processing.imputation import (impute_data_using_rule, 
                                  interpolation_rule_SL1, interpolate_linear)
from processing.outliers_filtering import filter_outliers
from processing.utils import add_Country_from_ISO

# %%
df = pd.read_csv(f'data/indicator/SL2/preprocessed/SL2_origin.M.csv')
df = impute_data_using_rule(df, interpolate_linear)

# %%
df = filter_outliers(df)

# %%
sns.scatterplot(data=df[df.ISO == 'CIV'], x='Year', y='Value', hue='Corrected')
plt.show()

# %%
test = filter_outliers(test)

plt.plot(test['Year'], test['Value'], label='raw')
plt.plot(test['Year'], test['filtered_Value'], label='MAD')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1272b3a23cb6> in <module>
# ----> 1 test = filter_outliers(test)
#       2
#       3 plt.plot(test['Year'], test['Value'], label='raw')
#       4 plt.plot(test['Year'], test['filtered_Value'], label='MAD')
#
# NameError: name 'test' is not defined

# %%
hampel(df['Value'].reset_index(drop=True), window_size=3, n=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-31acdfd76933> in <module>
# ----> 1 hampel(df['Value'].reset_index(drop=True), window_size=3, n=1)
#
# NameError: name 'hampel' is not defined

# %%
df.groupby('ISO').apply(lambda group:

# %%
def remove_outliers(df):

# %%
os.listdir('data/indicator/SL2/preprocessed/')

# %%
from scipy.signal import savgol_filter, bspline, spline_filter
from hampel import hampel
test = df[df.ISO == 'COM']

# %%
test['savgol_filter'] = savgol_filter(test['Value'].values, 9, 2)
#test['bspline'] = spline_filter(test['Value'].values, 3)
test['MAD'] = hampel(test['Value'].reset_index(drop=True), window_size=3, n=1).values

# %%
plt.plot(test['Year'], test['Value'], label='raw')
plt.plot(test['Year'], test['savgol_filter'], label='savgol_filter')
plt.plot(test['Year'], test['MAD'], label='MAD')
#plt.plot(test['Year'], test['bspline'], label='bspline')

plt.legend()

# %%
df[df.ISO == 'BOL'].plot.scatter(x='Year', y='Value')
