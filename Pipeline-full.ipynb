# %%
import pandas as pd
import os
import json

# %%
from tasks.download import download_data
from tasks.process import process_files 
from tasks.compute_index import compute_index

# %%
download_data(fresh_start=False)

# %%
from tasks.preprocess_v2 import preprocess_MANUAL_files

preprocess_MANUAL_files()

# %%
from tasks.preprocess_v2 import process_APIs_raw_data

# %%
process_APIs_raw_data()

# %%
# compute_indicators()

# %%
from tasks.process_v2 import process_files
process_files()

# %%
compute_index(save=True)

# %%
from tasks.post_process import make_timeseries_excel, make_imputation_report

make_timeseries_excel()
make_imputation_report()
# Out:
# AB1
# AB2
# /home/simon/Work/GGGI/Anticipe/tasks/post_process.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# AB3
# BE1
# BE2
# BE3
# CV1
# CV2
# CV3
# EE1
# EE2
# EQ1
# EQ2
# EQ3
# EW1
# EW2
# GB1
# GB2
# GB3
# GE1
# GE2
# GE3
# GJ1
# GN1
