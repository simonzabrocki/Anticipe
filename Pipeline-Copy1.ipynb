# %%
import pandas as pd
import os
import json

# %%
from tasks.download import download_data
from tasks.process import process_files 
from tasks.compute_index import compute_index

# %%
download_data(fresh_start=False)

# %%
from tasks.preprocess_v2 import preprocess_MANUAL_files

preprocess_MANUAL_files()

# %%
from tasks.preprocess_v2 import process_APIs_raw_data

# %%
process_APIs_raw_data()

# %%
# compute_indicators()

# %%
from tasks.process_v2 import process_files
process_files()
# Out:
# Processing GV1:
# 	 Processing GV1_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/GV1/processed/GV1_WB.csv
# Processing EE2:
# 	 Processing EE2_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/EE2/processed/EE2_WB.csv
# 	 Processing EE2_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/EE2/processed/EE2_SDG.csv
# Processing SE2:
# 	 Processing sub indicators from SE2.0_WB.csv, SE2.1_WB.csv, SE2.2_WB.csv, SE2.3_WB.csv, SE2.4_WB.csv, SE2.5_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing SE2 for SE2_WB.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/SE2/processed/SE2_WB.csv
# 	 Processing sub indicators from SE2.0_SDG.csv, SE2.1_SDG.csv, SE2.2_SDG.csv, SE2.3_SDG.csv, SE2.4_SDG.csv, SE2.5_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing SE2 for SE2_SDG.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/SE2/processed/SE2_SDG.csv
# Processing CV2:
# 	 Processing CV2_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/CV2/processed/CV2_origin.M.csv
# Processing ME1:
# 	 Processing ME1_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/ME1/processed/ME1_origin.M.csv
# Processing BE3:
# 	 Processing BE3_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/BE3/processed/BE3_SDG.csv
# Processing ME2:
# 	 Processing ME2_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/ME2/processed/ME2_origin.M.csv
# Processing BE2:
# 	 Processing BE2_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/BE2/processed/BE2_WB.csv
# 	 Processing BE2_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/BE2/processed/BE2_SDG.csv
# Processing SP1:
# 	 Processing SP1_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/SP1/processed/SP1_SDG.csv
# Processing EW1:
# 	 Processing EW1_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/EW1/processed/EW1_SDG.csv
# Processing EQ1:
# 	 Processing EQ1_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/EQ1/processed/EQ1_WB.csv
# 	 Processing EQ1_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/EQ1/processed/EQ1_SDG.csv
# Processing CV3:
# 	 Processing CV3_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/CV3/processed/CV3_WB.csv
# Processing SE1:
# 	 Processing sub indicators from SE1.0_WB.csv, SE1.1_WB.csv, SE1.2_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing SE1 for SE1.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/SE1/processed/SE1.csv
# Processing CV1:
# 	 Processing CV1_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/CV1/processed/CV1_SDG.csv
# Processing GT1:
# 	 Processing GT1_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/GT1/processed/GT1_origin.M.csv
# Processing SP3:
# 	 Processing SP3_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/SP3/processed/SP3_SDG.csv
# Processing SE3:
# 	 Processing SE3_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/SE3/processed/SE3_SDG.csv
# Processing GB3:
# 	 Processing GB3_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/GB3/processed/GB3_origin.M.csv
# Processing GE1:
# 	 Processing sub indicators from GE1.0_CW.csv, GE1.1_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing GE1 for GE1.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/GE1/processed/GE1.csv
# Processing GB2:
# 	 Processing sub indicators from GB2.0_WB.csv, GB2.1_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing GB2 for GB2_WB.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/GB2/processed/GB2_WB.csv
# 	 Processing sub indicators from GB2.0_SDG.csv, GB2.1_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing GB2 for GB2_SDG.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/GB2/processed/GB2_SDG.csv
# Processing GJ1:
# 	 Processing GJ1_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/GJ1/processed/GJ1_origin.M.csv
# Processing SP2:
# 	 Processing SP2_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/SP2/processed/SP2_origin.M.csv
# 	 Processing SP2_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/SP2/processed/SP2_SDG.csv
# Processing EW2:
# 	 Processing EW2_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/EW2/processed/EW2_WB.csv
# 	 Processing EW2_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/EW2/processed/EW2_SDG.csv
# Processing EE1:
# 	 Processing EE1_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/EE1/processed/EE1_SDG.csv
# Processing SL1:
# 	 Processing SL1_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/SL1/processed/SL1_origin.M.csv
# Processing AB3:
# 	 Processing sub indicators from AB3.0_WB.csv, AB3.1_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing AB3 for AB3.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/AB3/processed/AB3.csv
# Processing AB2:
# 	 Processing sub indicators from AB2.0_SDG.csv, AB2.1_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing AB2 for AB2_SDG.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/AB2/processed/AB2_SDG.csv
# 	 Processing sub indicators from AB2.0_WB.csv, AB2.1_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing AB2 for AB2_WB.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/AB2/processed/AB2_WB.csv
# Processing EQ2:
# 	 Processing EQ2_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/EQ2/processed/EQ2_origin.M.csv
# Processing AB1:
# 	 Processing sub indicators from AB1.0_SDG.csv, AB1.1_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing AB1 for AB1_SDG.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/AB1/processed/AB1_SDG.csv
# 	 Processing sub indicators from AB1.0_WB.csv, AB1.1_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing AB1 for AB1_WB.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/AB1/processed/AB1_WB.csv
# Processing SL2:
# 	 Processing SL2_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/SL2/processed/SL2_origin.M.csv
# Processing EQ3:
# 	 Processing EQ3_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/EQ3/processed/EQ3_origin.M.csv
# Processing GB1:
# 	 Processing GB1_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/GB1/processed/GB1_SDG.csv
# 	 Processing GB1_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/GB1/processed/GB1_WB.csv
# Processing BE1:
# 	 Processing sub indicators from BE1.0_SDG.csv, BE1.1_SDG.csv, BE1.2_SDG.csv, BE1.3_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing BE1 for BE1.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/BE1/processed/BE1.csv
# Processing GE3:
# 	 Processing sub indicators from GE3.1_CW.csv, GE3.0_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing GE3 for GE3.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/GE3/processed/GE3.csv
# Processing GE2:
# 	 Processing sub indicators from GE2.0_CW.csv, GE2.1_WB.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Formatting:DONE
# 	 Computing GE2 for GE2.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/GE2/processed/GE2.csv
# Processing GN1:
# 	 Processing GN1_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/GN1/processed/GN1_origin.M.csv

# %%
compute_index()
# Out:
# Computing Index:Collecting data:Saving at data/full_data/data.csv
# Computation: saving at data/full_data/result.csv

# %% [markdown]
# # Test

# %%
process_files()
