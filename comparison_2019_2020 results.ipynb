# %%
import pandas as pd

# %%
result_2019 = pd.read_csv('./data/2019_archive/result.csv')
result_2020 = pd.read_csv(f'result_2020.csv')

# %% [markdown]
# Compare by countries using Variable: index

# %%
result_2020.query("Country == 'Norway'  and Variable == 'Index' ")  # result_2019.query("Country == 'Norway'  and Variable == 'Index' ")
# Out:
#         ISO Variable      Value Aggregation    Year Country Continent  \
# 284740  NOR    Index  73.893651       Index  2009.0  Norway    Europe
# 284849  NOR    Index  74.066524       Index  2010.0  Norway    Europe
# 284958  NOR    Index  73.455695       Index  2011.0  Norway    Europe
# 285067  NOR    Index  73.637529       Index  2012.0  Norway    Europe
# 285176  NOR    Index  72.805304       Index  2013.0  Norway    Europe
# 285285  NOR    Index  73.115815       Index  2014.0  Norway    Europe
# 285394  NOR    Index  72.874873       Index  2015.0  Norway    Europe
# 285503  NOR    Index  72.794557       Index  2016.0  Norway    Europe
# 285612  NOR    Index  72.772993       Index  2017.0  Norway    Europe
# 285721  NOR    Index  72.686342       Index  2018.0  Norway    Europe
# 285830  NOR    Index  72.929717       Index  2019.0  Norway    Europe
# 285939  NOR    Index  72.899203       Index  2020.0  Norway    Europe
#
# ...

# %%
result_2020.query("Country == 'Rwanda'  and Variable == 'Index' ")  # result_2019.query("Country == 'Rwanda'  and Variable == 'Index' ")
# Out:
#         ISO Variable      Value Aggregation    Year Country Continent  \
# 315969  RWA    Index  54.473402       Index  2009.0  Rwanda    Africa
# 316078  RWA    Index  54.742372       Index  2010.0  Rwanda    Africa
# 316187  RWA    Index  53.958489       Index  2011.0  Rwanda    Africa
# 316296  RWA    Index  54.455694       Index  2012.0  Rwanda    Africa
# 316405  RWA    Index  55.190559       Index  2013.0  Rwanda    Africa
# 316514  RWA    Index  55.600135       Index  2014.0  Rwanda    Africa
# 316623  RWA    Index  52.503642       Index  2015.0  Rwanda    Africa
# 316732  RWA    Index  52.570519       Index  2016.0  Rwanda    Africa
# 316841  RWA    Index  52.699252       Index  2017.0  Rwanda    Africa
# 316950  RWA    Index  53.631436       Index  2018.0  Rwanda    Africa
# 317059  RWA    Index  53.579009       Index  2019.0  Rwanda    Africa
# 317168  RWA    Index  53.578850       Index  2020.0  Rwanda    Africa
#
#               UNregion IncomeLevel               Region
# ...

# %%
result_2020.query("Country == 'France'  and Variable == 'Index' ")  # result_2019.query("Country == 'France'  and Variable == 'Index' ")
# Out:
#         ISO Variable      Value Aggregation    Year Country Continent  \
# 130435  FRA    Index  72.006032       Index  2009.0  France    Europe
# 130544  FRA    Index  72.812948       Index  2010.0  France    Europe
# 130653  FRA    Index  72.164454       Index  2011.0  France    Europe
# 130762  FRA    Index  72.407191       Index  2012.0  France    Europe
# 130871  FRA    Index  72.250106       Index  2013.0  France    Europe
# 130980  FRA    Index  72.517175       Index  2014.0  France    Europe
# 131089  FRA    Index  73.431044       Index  2015.0  France    Europe
# 131198  FRA    Index  73.573212       Index  2016.0  France    Europe
# 131307  FRA    Index  73.863041       Index  2017.0  France    Europe
# 131416  FRA    Index  74.693182       Index  2018.0  France    Europe
# 131525  FRA    Index  74.906619       Index  2019.0  France    Europe
# 131634  FRA    Index  75.019473       Index  2020.0  France    Europe
#
# ...

# %%
result_2020.query("Country == 'Senegal'  and Variable == 'Index' and Year == 2019 ")  # result_2019.query("Country == 'Senegal'  and Variable == 'Index' and Year == 2019 ")
# Out:
#         ISO Variable      Value Aggregation    Year  Country Continent  \
# 327451  SEN    Index  57.002966       Index  2019.0  Senegal    Africa
#
#               UNregion          IncomeLevel               Region
# 327451  Western Africa  Lower middle income  Sub-Saharan Africa

# %% [markdown]
# rank of Top 10 countries based on Value for 2020 and 2019

# %%
result_2020.nlargest(10, ['Value']) 
# result_2019.nlargest(10, ['Value'])
# Out:
#         ISO Variable         Value Aggregation    Year Country Continent  \
# 73008   TCD      EQ2  10751.484954   Indicator  2007.0    Chad    Africa
# 72900   TCD      EQ2  10731.869664   Indicator  2006.0    Chad    Africa
# 72792   TCD      EQ2  10693.362753   Indicator  2005.0    Chad    Africa
# 73116   TCD      EQ2  10513.252554   Indicator  2008.0    Chad    Africa
# 273929  NER      EQ2  10394.899163   Indicator  2005.0   Niger    Africa
# 73224   TCD      EQ2  10294.643412   Indicator  2009.0    Chad    Africa
# 73332   TCD      EQ2  10124.964661   Indicator  2010.0    Chad    Africa
# 73440   TCD      EQ2   9830.152116   Indicator  2011.0    Chad    Africa
# 274037  NER      EQ2   9789.447820   Indicator  2006.0   Niger    Africa
# 73548   TCD      EQ2   9354.105679   Indicator  2012.0    Chad    Africa
#
#               UNregion IncomeLevel               Region
# 73008    Middle Africa  Low income  Sub-Saharan Africa
# ...

# %% [markdown]
# rank of last 10 countries based on Value for 2020 and 2019

# %%
result_2020.nsmallest(10, ['Value'])
# result_2020.nsmallest(10, ['Value'])
# Out:
#         ISO Variable      Value Aggregation    Year  Country Continent  \
# 213268  LBR      GV1 -96.084072   Indicator  2005.0  Liberia    Africa
# 213376  LBR      GV1 -95.932609   Indicator  2006.0  Liberia    Africa
# 213484  LBR      GV1 -95.781146   Indicator  2007.0  Liberia    Africa
# 214672  LBR      GV1 -75.409955   Indicator  2018.0  Liberia    Africa
# 214780  LBR      GV1 -75.409955   Indicator  2019.0  Liberia    Africa
# 214888  LBR      GV1 -75.409955   Indicator  2020.0  Liberia    Africa
# 214564  LBR      GV1 -74.479211   Indicator  2017.0  Liberia    Africa
# 214240  LBR      GV1 -73.548467   Indicator  2014.0  Liberia    Africa
# 214456  LBR      GV1 -71.858790   Indicator  2016.0  Liberia    Africa
# 214132  LBR      GV1 -61.033403   Indicator  2013.0  Liberia    Africa
#
#               UNregion IncomeLevel               Region
# 213268  Western Africa  Low income  Sub-Saharan Africa
# 213376  Western Africa  Low income  Sub-Saharan Africa
# ...

# %% [markdown]
# 2020 result data: rank of Top 10 countries based on Aggregation = Dimension , for year = 2020

# %%
top_10_2020_Dimension = (result_2020.query("Aggregation == 'Dimension' and Year == 2020 ")).nlargest(10, ['Value'])
top_10_2020_Dimension
# Out:
#         ISO Variable      Value Aggregation    Year      Country Continent  \
# 370967  SWE       SI  94.254454   Dimension  2020.0       Sweden    Europe
# 286044  NOR       SI  93.430041   Dimension  2020.0       Norway    Europe
# 268706  NLD       SI  93.005820   Dimension  2020.0  Netherlands    Europe
# 69319   CAN       SI  91.303668   Dimension  2020.0       Canada   America
# 221898  LUX       SI  91.283594   Dimension  2020.0   Luxembourg    Europe
# 372707  CHE       SI  91.054489   Dimension  2020.0  Switzerland    Europe
# 339805  SVN       SI  90.530856   Dimension  2020.0     Slovenia    Europe
# 102246  DNK       SI  90.430526   Dimension  2020.0      Denmark    Europe
# 143870  DEU       SI  90.414611   Dimension  2020.0      Germany    Europe
# 131739  FRA       SI  90.228042   Dimension  2020.0       France    Europe
#
#                 UNregion  IncomeLevel                 Region
# 370967   Northern Europe  High income  Europe & Central Asia
# ...

# %% [markdown]
# 2019 result data: rank of Top 10 countries based on Aggregation = Dimension , for year = 2020

# %%
top_10_2019_Dimension = (result_2019.query("Aggregation == 'Dimension' and Year == 2020 ")).nlargest(10, ['Value'])
top_10_2019_Dimension
# Out:
#         ISO Variable  Value Aggregation    Year      Country Continent  \
# 109520  FIN       SI  93.27   Dimension  2020.0      Finland    Europe
# 224980  NLD       SI  93.27   Dimension  2020.0  Netherlands    Europe
# 310768  SWE       SI  93.23   Dimension  2020.0       Sweden    Europe
# 312256  CHE       SI  91.69   Dimension  2020.0  Switzerland    Europe
# 239780  NOR       SI  91.46   Dimension  2020.0       Norway    Europe
# 85850   DNK       SI  91.28   Dimension  2020.0      Denmark    Europe
# 29625   BEL       SI  90.93   Dimension  2020.0      Belgium    Europe
# 185028  LUX       SI  90.76   Dimension  2020.0   Luxembourg    Europe
# 111008  FRA       SI  90.52   Dimension  2020.0       France    Europe
# 294544  ESP       SI  90.46   Dimension  2020.0        Spain    Europe
#
#                UNregion  IncomeLevel                 Region
# 109520  Northern Europe  High income  Europe & Central Asia
# 224980   Western Europe  High income  Europe & Central Asia
# ...

# %% [markdown]
# 2020 result data: rank of Top 10 countries based on Aggregation = Category , for year = 2020

# %%
top_10_2020_category = (result_2020.query("Aggregation == 'Category' and Year == 2020 ")).nlargest(10, ['Value'])
top_10_2020_category
# Out:
#         ISO Variable       Value Aggregation    Year               Country  \
# 175037  ISL       GN  100.000000    Category  2020.0               Iceland
# 221887  LUX       EW  100.000000    Category  2020.0            Luxembourg
# 265217  NRU       GE  100.000000    Category  2020.0                 Nauru
# 372696  CHE       EW  100.000000    Category  2020.0           Switzerland
# 372699  CHE       GJ  100.000000    Category  2020.0           Switzerland
# 403880  ARE       SE   99.933622    Category  2020.0  United Arab Emirates
# 225348  MKD       GT   99.910075    Category  2020.0             Macedonia
# 86633   COG       SL   99.899949    Category  2020.0        Congo Republic
# 45039   BOL       GB   99.880983    Category  2020.0               Bolivia
# 34654   BLR       SE   99.877481    Category  2020.0               Belarus
#
#        Continent         UNregion          IncomeLevel  \
# 175037    Europe  Northern Europe          High income
# ...

# %% [markdown]
# 2019 result data: rank of Top 10 countries based on Aggregation = Category , for year = 2020

# %%
top_10_2019_category = (result_2019.query("Aggregation == 'Category' and Year == 2020 ")).nlargest(10, ['Value'])
top_10_2019_category
# Out:
#         ISO Variable  Value Aggregation    Year       Country Continent  \
# 29618   BEL       GN  100.0    Category  2020.0       Belgium    Europe
# 85839   DNK       EW  100.0    Category  2020.0       Denmark    Europe
# 87317   DJI       GV  100.0    Category  2020.0      Djibouti    Africa
# 137580  GUY       BE  100.0    Category  2020.0        Guyana   America
# 144997  ISL       GN  100.0    Category  2020.0       Iceland    Europe
# 185017  LUX       EW  100.0    Category  2020.0    Luxembourg    Europe
# 186484  MAC       AB  100.0    Category  2020.0         Macao      Asia
# 187966  MKD       GT  100.0    Category  2020.0     Macedonia    Europe
# 267905  MAF       CV  100.0    Category  2020.0  Saint-Martin   America
# 269389  WSM       SL  100.0    Category  2020.0         Samoa   Oceania
#
#                UNregion          IncomeLevel                      Region
# 29618    Western Europe          High income       Europe & Central Asia
# ...

# %% [markdown]
# 2020 result data: rank of Top 10 countries based on Aggregation = index , for year = 2020

# %%
top_10_2020_index = (result_2020.query("Variable == 'Index' and Aggregation == 'Index' and Year == 2020 ")).nlargest(10, ['Value'])
top_10_2020_index
# Out:
#         ISO Variable      Value Aggregation    Year         Country Continent  \
# 370862  SWE    Index  82.532940       Index  2020.0          Sweden    Europe
# 24161   AUT    Index  81.519972       Index  2020.0         Austria    Europe
# 372602  CHE    Index  81.021450       Index  2020.0     Switzerland    Europe
# 102141  DNK    Index  79.351938       Index  2020.0         Denmark    Europe
# 143765  DEU    Index  79.206639       Index  2020.0         Germany    Europe
# 100401  CZE    Index  79.178474       Index  2020.0  Czech Republic    Europe
# 129894  FIN    Index  78.779526       Index  2020.0         Finland    Europe
# 337960  SVK    Index  78.665286       Index  2020.0        Slovakia    Europe
# 209649  LVA    Index  76.182683       Index  2020.0          Latvia    Europe
# 188823  ITA    Index  75.857094       Index  2020.0           Italy    Europe
#
#                UNregion  IncomeLevel                 Region
# ...

# %% [markdown]
# 2019 result data: rank of Top 10 countries based on Aggregation = Index , for year = 2020

# %%
top_10_2019_index = (result_2019.query("Aggregation == 'Index' and Year == 2020 ")).nlargest(10, ['Value'])
top_10_2019_index
# Out:
#         ISO Variable  Value Aggregation    Year         Country Continent  \
# 310679  SWE    Index  78.54       Index  2020.0          Sweden    Europe
# 84273   CZE    Index  76.96       Index  2020.0  Czech Republic    Europe
# 85761   DNK    Index  76.54       Index  2020.0         Denmark    Europe
# 119794  DEU    Index  75.81       Index  2020.0         Germany    Europe
# 19160   AUT    Index  75.43       Index  2020.0         Austria    Europe
# 109431  FIN    Index  74.89       Index  2020.0         Finland    Europe
# 284086  SVK    Index  74.19       Index  2020.0        Slovakia    Europe
# 312167  CHE    Index  73.35       Index  2020.0     Switzerland    Europe
# 183451  LTU    Index  71.97       Index  2020.0       Lithuania    Europe
# 285574  SVN    Index  71.00       Index  2020.0        Slovenia    Europe
#
#                UNregion  IncomeLevel                 Region
# 310679  Northern Europe  High income  Europe & Central Asia
# ...

# %% [markdown]
# 2019 result data: rank of last 10 countries based on Aggregation = Index , for year = 2020

# %%
last_10_2019_index = (result_2019.query("Aggregation == 'Index' and Year == 2020 ")).nsmallest(10, ['Value'])
last_10_2019_index
# Out:
#         ISO Variable  Value Aggregation    Year              Country  \
# 230827  NER    Index  24.46       Index  2020.0                Niger
# 346214  UZB    Index  25.83       Index  2020.0           Uzbekistan
# 1387    AFG    Index  27.58       Index  2020.0          Afghanistan
# 4364    DZA    Index  28.00       Index  2020.0              Algeria
# 232315  NGA    Index  28.11       Index  2020.0              Nigeria
# 316599  TJK    Index  29.03       Index  2020.0           Tajikistan
# 242662  PAK    Index  29.50       Index  2020.0             Pakistan
# 326951  TTO    Index  30.30       Index  2020.0  Trinidad and Tobago
# 359510  ZWE    Index  30.55       Index  2020.0             Zimbabwe
# 51713   BDI    Index  31.26       Index  2020.0              Burundi
#
#        Continent         UNregion          IncomeLevel  \
# 230827    Africa   Western Africa           Low income
# 346214      Asia     Central Asia  Lower middle income
# ...

# %% [markdown]
# 2020 result data: rank of last 10 countries based on Aggregation = Index , for year = 2020

# %%
last_10_2020_index = (result_2020.query("Aggregation == 'Index' and Year == 2020 ")).nsmallest(10, ['Value'])
last_10_2020_index
# Out:
#         ISO Variable      Value Aggregation    Year       Country Continent  \
# 289413  PAK    Index  41.534192       Index  2020.0      Pakistan      Asia
# 275547  NER    Index  44.297702       Index  2020.0         Niger    Africa
# 226989  MDG    Index  44.595949       Index  2020.0    Madagascar    Africa
# 325820  SAU    Index  44.827421       Index  2020.0  Saudi Arabia      Asia
# 287673  OMN    Index  45.338607       Index  2020.0          Oman      Asia
# 112545  EGY    Index  46.385157       Index  2020.0         Egypt    Africa
# 204431  KWT    Index  46.608071       Index  2020.0        Kuwait      Asia
# 121219  SWZ    Index  46.658088       Index  2020.0      Eswatini    Africa
# 414191  UZB    Index  47.358427       Index  2020.0    Uzbekistan      Asia
# 176679  IND    Index  48.657638       Index  2020.0         India      Asia
#
#                UNregion          IncomeLevel                      Region
# ...
