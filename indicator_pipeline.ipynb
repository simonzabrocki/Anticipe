# %%
from tasks.download import download_indicator
from tasks.preprocess import preprocess_APIs_data_in_indicator, preprocess_MANUAL_data_in_indicator
from tasks.process import process_indicator

import pandas as pd

# %%
def indicator_pipeline(indicator, fresh_start=True):
    
    print(f'Downloading..')
    download_indicator(indicator, fresh_start)
    
    print('Preprocessing...')
    preprocess_MANUAL_data_in_indicator(indicator)
    preprocess_APIs_data_in_indicator(indicator)
    
    print('Processing...')
    process_indicator(indicator)

# %%
indicator_pipeline("SL1", fresh_start=False)
# Out:
# Downloading..
# Downloading SL1's data: DONE
# Preprocessing...
# PreProcessing SL1 Manual files: Saving at data/indicator/SL1/preprocessed/SL1_origin.M.csv
# Done
# Processing...
# Processing SL1:
# 	 Processing SL1_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/SL1/processed/SL1_origin.M.csv

# %%
pd.read_csv('data/indicator/ME2/preprocessed/ME2_origin.M.csv').query("ISO == 'FRA'")
# Out:
#       ISO                               Description  Year      Value Variable  \
# 1196  FRA  Total material footprint (MF) per capita  1990  17.034240      ME2
# 1197  FRA  Total material footprint (MF) per capita  1991  17.360431      ME2
# 1198  FRA  Total material footprint (MF) per capita  1992  19.902707      ME2
# 1199  FRA  Total material footprint (MF) per capita  1993  18.749216      ME2
# 1200  FRA  Total material footprint (MF) per capita  1994  18.855029      ME2
# 1201  FRA  Total material footprint (MF) per capita  1995  21.092498      ME2
# 1202  FRA  Total material footprint (MF) per capita  1996  19.065489      ME2
# 1203  FRA  Total material footprint (MF) per capita  1997  17.789807      ME2
# 1204  FRA  Total material footprint (MF) per capita  1998  19.197151      ME2
# 1205  FRA  Total material footprint (MF) per capita  1999  19.541595      ME2
# 1206  FRA  Total material footprint (MF) per capita  2000  20.074942      ME2
# 1207  FRA  Total material footprint (MF) per capita  2001  19.256486      ME2
# 1208  FRA  Total material footprint (MF) per capita  2002  20.011915      ME2
# 1209  FRA  Total material footprint (MF) per capita  2003  20.800081      ME2
# 1210  FRA  Total material footprint (MF) per capita  2004  21.619826      ME2
# 1211  FRA  Total material footprint (MF) per capita  2005  21.791292      ME2
# 1212  FRA  Total material footprint (MF) per capita  2006  22.074326      ME2
# 1213  FRA  Total material footprint (MF) per capita  2007  22.792834      ME2
# 1214  FRA  Total material footprint (MF) per capita  2008  22.808010      ME2
# 1215  FRA  Total material footprint (MF) per capita  2009  21.983138      ME2
# 1216  FRA  Total material footprint (MF) per capita  2010  20.933964      ME2
# 1217  FRA  Total material footprint (MF) per capita  2011  20.512339      ME2
# 1218  FRA  Total material footprint (MF) per capita  2012  20.568121      ME2
# 1219  FRA  Total material footprint (MF) per capita  2013  20.692157      ME2
# 1220  FRA  Total material footprint (MF) per capita  2014  20.915107      ME2
# 1221  FRA  Total material footprint (MF) per capita  2015  21.185202      ME2
#
#                                                  Source  \
# 1196  U.N. Environment: Secretariat of the Internati...
# 1197  U.N. Environment: Secretariat of the Internati...
# 1198  U.N. Environment: Secretariat of the Internati...
# 1199  U.N. Environment: Secretariat of the Internati...
# 1200  U.N. Environment: Secretariat of the Internati...
# 1201  U.N. Environment: Secretariat of the Internati...
# 1202  U.N. Environment: Secretariat of the Internati...
# 1203  U.N. Environment: Secretariat of the Internati...
# 1204  U.N. Environment: Secretariat of the Internati...
# 1205  U.N. Environment: Secretariat of the Internati...
# 1206  U.N. Environment: Secretariat of the Internati...
# 1207  U.N. Environment: Secretariat of the Internati...
# 1208  U.N. Environment: Secretariat of the Internati...
# 1209  U.N. Environment: Secretariat of the Internati...
# 1210  U.N. Environment: Secretariat of the Internati...
# 1211  U.N. Environment: Secretariat of the Internati...
# 1212  U.N. Environment: Secretariat of the Internati...
# 1213  U.N. Environment: Secretariat of the Internati...
# 1214  U.N. Environment: Secretariat of the Internati...
# 1215  U.N. Environment: Secretariat of the Internati...
# 1216  U.N. Environment: Secretariat of the Internati...
# 1217  U.N. Environment: Secretariat of the Internati...
# 1218  U.N. Environment: Secretariat of the Internati...
# 1219  U.N. Environment: Secretariat of the Internati...
# 1220  U.N. Environment: Secretariat of the Internati...
# 1221  U.N. Environment: Secretariat of the Internati...
#
#                                                     URL    From
# 1196  https://www.resourcepanel.org/global-material-...  MANUAL
# 1197  https://www.resourcepanel.org/global-material-...  MANUAL
# 1198  https://www.resourcepanel.org/global-material-...  MANUAL
# 1199  https://www.resourcepanel.org/global-material-...  MANUAL
# 1200  https://www.resourcepanel.org/global-material-...  MANUAL
# 1201  https://www.resourcepanel.org/global-material-...  MANUAL
# 1202  https://www.resourcepanel.org/global-material-...  MANUAL
# 1203  https://www.resourcepanel.org/global-material-...  MANUAL
# 1204  https://www.resourcepanel.org/global-material-...  MANUAL
# 1205  https://www.resourcepanel.org/global-material-...  MANUAL
# 1206  https://www.resourcepanel.org/global-material-...  MANUAL
# 1207  https://www.resourcepanel.org/global-material-...  MANUAL
# 1208  https://www.resourcepanel.org/global-material-...  MANUAL
# 1209  https://www.resourcepanel.org/global-material-...  MANUAL
# 1210  https://www.resourcepanel.org/global-material-...  MANUAL
# 1211  https://www.resourcepanel.org/global-material-...  MANUAL
# 1212  https://www.resourcepanel.org/global-material-...  MANUAL
# 1213  https://www.resourcepanel.org/global-material-...  MANUAL
# 1214  https://www.resourcepanel.org/global-material-...  MANUAL
# 1215  https://www.resourcepanel.org/global-material-...  MANUAL
# 1216  https://www.resourcepanel.org/global-material-...  MANUAL
# 1217  https://www.resourcepanel.org/global-material-...  MANUAL
# 1218  https://www.resourcepanel.org/global-material-...  MANUAL
# 1219  https://www.resourcepanel.org/global-material-...  MANUAL
# 1220  https://www.resourcepanel.org/global-material-...  MANUAL
# 1221  https://www.resourcepanel.org/global-material-...  MANUAL

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GJ1/processed/GJ1_origin.M.csv')

# %%
test.query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GE1/processed/GE1.csv')

# %%
test.query("ISO == 'DEU'")
