# %%
from tasks.download import download_indicator
from tasks.preprocess import preprocess_APIs_data_in_indicator, preprocess_MANUAL_data_in_indicator
from tasks.process import process_indicator
from tasks.compute_indicators import compute_indicator
import pandas as pd

# %%
def indicator_pipeline(indicator, fresh_start=True):
    
    print(f'Downloading..')
    download_indicator(indicator, fresh_start)
    
    print('Preprocessing...')
    preprocess_MANUAL_data_in_indicator(indicator)
    preprocess_APIs_data_in_indicator(indicator)
    
    print('Processing...')
    process_indicator(indicator)

# %%
#compute_indicator('AB1')

# %%
indicator_pipeline("ME3", fresh_start=False)
# Out:
# Downloading..
# Downloading ME3's data: ME3.0_SDG.json already there
# ME3.1_SDG.json already there
# DONE
# Preprocessing...
# PreProcessing ME3 Manual files: Saving at data/indicator/ME3/preprocessed/ME3.2_origin.M.csv
# Done
# PreProcessing data/indicator/ME3/raw/ME3.2_SDG.json: Saving at data/indicator/ME3/preprocessed/ME3.2_SDG.csv
# Done
# PreProcessing data/indicator/ME3/raw/ME3.1_SDG.json: Saving at data/indicator/ME3/preprocessed/ME3.1_SDG.csv
# Done
# PreProcessing data/indicator/ME3/raw/ME3.0_SDG.json: Saving at data/indicator/ME3/preprocessed/ME3.0_SDG.csv
# Done
# Processing...
# Processing ME3:
# 	 Processing ME3.1_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/ME3/processed/ME3.1_SDG.csv
# 	 Processing ME3.2_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/ME3/processed/ME3.2_origin.M.csv
# 	 Processing ME3.2_SDG.csv
# 	 Imputation:'Year'
# 	 Outlier removal:"['Value'] not found in axis"
# 	 Formatting:DONE
# 	 saving at data/indicator/ME3/processed/ME3.2_SDG.csv
# 	 Processing ME3.0_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/ME3/processed/ME3.0_SDG.csv
# 	 Processing ME3_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/ME3/processed/ME3_origin.M.csv

# %%
pd.read_csv('data/indicator/AB3/processed/AB3_origin.M.csv')#.dropna()

# %%
pd.read_csv('data/indicator/AB1/preprocessed/AB1.3_SDG.csv').Description.unique()

# %%
import json

with open('data/indicator/GJ3/raw/GJ3_SDG.json') as json_file:
    data = json.load(json_file)

# %%
data['data']

# %%
data

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/ME2/preprocessed/ME2_origin.M.csv').query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GJ1/processed/GJ1_origin.M.csv')

# %%
test.query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GE1/processed/GE1.csv')

# %%
test.query("ISO == 'DEU'")
