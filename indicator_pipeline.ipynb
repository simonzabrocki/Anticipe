# %%
from tasks.pipeline import indicator_pipeline
from tasks.compute_indicators import compute_indicator
import pandas as pd
#compute_indicator('AB1')
#indicator_pipeline('ME3')

# %%
indicator_pipeline('GJ2', fresh_start=True)
# Out:
# Downloading..
# Downloading GJ2's data: Downloading {'GGI_code': 'GJ2', 'params': {'dimensions': "[{name:'Age',values:['15+']}, {name:'Sex',values:['BOTHSEX']}]", 'seriesCode': 'SI_POV_EMP1'}} from SDG: DONE
# Saving at data/indicator/GJ2/raw/GJ2_SDG.json: DONE
# DONE
# Preprocessing...
# PreProcessing GJ2 Manual files: Error:  'NoneType' object is not subscriptable
# PreProcessing data/indicator/GJ2/raw/GJ2_SDG.json: Saving at data/indicator/GJ2/preprocessed/GJ2_SDG.csv
# Done
# Processing...
# Processing GJ2:
# 	 Processing GJ2_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/GJ2/processed/GJ2_SDG.csv

# %%
pd.read_csv('data/indicator/GV2/processed//GV2_SDG.csv')
# Out:
#       ISO  Year                                        Description  \
# 0     ABW  2000  Proportion of population covered by at least a...
# 1     ABW  2001  Proportion of population covered by at least a...
# 2     ABW  2002  Proportion of population covered by at least a...
# 3     ABW  2003  Proportion of population covered by at least a...
# 4     ABW  2004  Proportion of population covered by at least a...
# ...   ...   ...                                                ...
# 4245  ZWE  2016  Proportion of population covered by at least a...
# 4246  ZWE  2017  Proportion of population covered by at least a...
# 4247  ZWE  2018  Proportion of population covered by at least a...
# 4248  ZWE  2019  Proportion of population covered by at least a...
# 4249  ZWE  2020  Proportion of population covered by at least a...
#
#                                                  Source  \
# 0                                          ITU WTID2020
# 1                                          ITU WTID2020
# 2                                          ITU WTID2020
# 3                                          ITU WTID2020
# 4                                          ITU WTID2020
# ...                                                 ...
# 4245                                             POTRAZ
# 4246                                             POTRAZ
# 4247                                             POTRAZ
# 4248  Postal and Telecommunications Regulatory Autho...
# 4249                                       ITU WTID2020
#
#                                                     URL DownloadDate  \
# 0     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...          NaN
# 1     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...          NaN
# 2     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...          NaN
# 3     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...          NaN
# 4     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...          NaN
# ...                                                 ...          ...
# 4245  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-20
# 4246  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-20
# 4247  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-20
# 4248  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-20
# 4249  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...          NaN
#
#      Indicator     From  Imputed  Value  Corrected   Country
# 0          GV2  SDG API     True  90.00      False     Aruba
# 1          GV2  SDG API     True  90.00      False     Aruba
# 2          GV2  SDG API     True  90.00      False     Aruba
# 3          GV2  SDG API     True  90.00      False     Aruba
# 4          GV2  SDG API     True  90.00      False     Aruba
# ...        ...      ...      ...    ...        ...       ...
# 4245       GV2  SDG API    False  88.90      False  Zimbabwe
# 4246       GV2  SDG API    False  90.09      False  Zimbabwe
# 4247       GV2  SDG API    False  93.00      False  Zimbabwe
# 4248       GV2  SDG API    False  93.40      False  Zimbabwe
# 4249       GV2  SDG API     True  93.40      False  Zimbabwe
#
# [4250 rows x 12 columns]

# %%
cons

# %%
pd.read_csv('data/indicator/ME3/raw/ME3.0_SDG.csv')

# %%
get_waste_cons()

# %%
get_loss_prod()

# %%
indicator_pipeline("ME3", fresh_start=False)

# %%
from tasks.post_process import get_info_from_indictor_df

df_list = [
    pd.read_csv('data/indicator/ME2/processed/ME2.0_origin.M.csv'),
    pd.read_csv('data/indicator/ME2/processed/ME2.1_SDG.csv'),
    pd.read_csv('data/indicator/ME2/processed/ME2.2_SDG.csv')
]

pd.concat([get_info_from_indictor_df(df) for df in df_list])

# %%
pd.read_csv('data/indicator/ME2/processed/ME')

# %%
indicator_pipeline("SL3", fresh_start=False)

# %%
pd.read_csv('data/indicator/EE3/processed/EE3_origin.M.csv').dropna().query("ISO == 'FRA'")

# %%
pd.read_csv('data/indicator/GJ2/processed/GJ2_origin.M.csv').dropna()

# %%
pd.read_csv('data/indicator/AB3/preprocessed/AB3_origin.M.csv')

# %%
pd.read_csv('data/indicator/ME3/preprocessed/ME3.1_SDG.csv')

# %%
pd.read_csv('data/indicator/AB1/preprocessed/AB1.3_SDG.csv').Description.unique()

# %%
import json

with open('data/indicator/GJ3/raw/GJ3_SDG.json') as json_file:
    data = json.load(json_file)

# %%
data['data']

# %%
data

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/ME2/preprocessed/ME2_origin.M.csv').query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GJ1/processed/GJ1_origin.M.csv')

# %%
test.query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GE1/processed/GE1.csv')

# %%
test.query("ISO == 'DEU'")
