# %%
from tasks.download import download_indicator
from tasks.preprocess import preprocess_APIs_data_in_indicator, preprocess_MANUAL_data_in_indicator
from tasks.process import process_indicator

import pandas as pd

# %%
def indicator_pipeline(indicator, fresh_start=True):
    
    print(f'Downloading..')
    download_indicator(indicator, fresh_start)
    
    print('Preprocessing...')
    preprocess_MANUAL_data_in_indicator(indicator)
    preprocess_APIs_data_in_indicator(indicator)
    
    print('Processing...')
    process_indicator(indicator)

# %%
indicator_pipeline("GN3", fresh_start=True)
# Out:
# Downloading..
# Downloading GN3's data: Downloading {'GGI_code': 'GN3', 'params': {'seriesCode': 'EG_EGY_RNEW'}} from SDG: DONE
# Saving at data/indicator/GN3/raw/GN3_SDG.json: DONE
# DONE
# Preprocessing...
# PreProcessing GN3 Manual files: Error:  'NoneType' object is not subscriptable
# PreProcessing data/indicator/GN3/raw/GN3_SDG.json: Saving at data/indicator/GN3/preprocessed/GN3_SDG.csv
# Done
# Processing...
# Processing GN3:
# 	 Processing GN3_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/GN3/processed/GN3_SDG.csv

# %%
pd.read_csv('data/indicator/GJ3/processed/GJ3_SDG.csv')
# Out:
#       ISO  Year                                        Description  \
# 0     AGO  2000  Employed population below international povert...
# 1     AGO  2001  Employed population below international povert...
# 2     AGO  2002  Employed population below international povert...
# 3     AGO  2003  Employed population below international povert...
# 4     AGO  2004  Employed population below international povert...
# ...   ...   ...                                                ...
# 2452  ZWE  2016  Employed population below international povert...
# 2453  ZWE  2017  Employed population below international povert...
# 2454  ZWE  2018  Employed population below international povert...
# 2455  ZWE  2019  Employed population below international povert...
# 2456  ZWE  2020  Employed population below international povert...
#
#                                                  Source  \
# 0     ILO modelled estimates, November 2020, availab...
# 1     ILO modelled estimates, November 2020, availab...
# 2     ILO modelled estimates, November 2020, availab...
# 3     ILO modelled estimates, November 2020, availab...
# 4     ILO modelled estimates, November 2020, availab...
# ...                                                 ...
# 2452  ILO modelled estimates, November 2020, availab...
# 2453  ILO modelled estimates, November 2020, availab...
# 2454  ILO modelled estimates, November 2020, availab...
# 2455  ILO modelled estimates, November 2020, availab...
# 2456  ILO modelled estimates, November 2020, availab...
#
#                                                     URL DownloadDate  \
# 0     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19
# 1     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19
# 2     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19
# 3     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19
# 4     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19
# ...                                                 ...          ...
# 2452  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19
# 2453  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19
# 2454  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19
# 2455  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...          NaN
# 2456  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...          NaN
#
#      Indicator     From  Imputed  Value  Corrected   Country
# 0          GJ3  SDG API    False  32.00      False    Angola
# 1          GJ3  SDG API    False  33.70      False    Angola
# 2          GJ3  SDG API    False  32.10      False    Angola
# 3          GJ3  SDG API    False  33.15       True    Angola
# 4          GJ3  SDG API    False  34.60      False    Angola
# ...        ...      ...      ...    ...        ...       ...
# 2452       GJ3  SDG API    False  28.60      False  Zimbabwe
# 2453       GJ3  SDG API    False  30.00      False  Zimbabwe
# 2454       GJ3  SDG API    False  27.80      False  Zimbabwe
# 2455       GJ3  SDG API     True  27.80      False  Zimbabwe
# 2456       GJ3  SDG API     True  27.80      False  Zimbabwe
#
# [2457 rows x 12 columns]

# %%
import json

with open('data/indicator/GJ3/raw/GJ3_SDG.json') as json_file:
    data = json.load(json_file)

# %%
data['data']
# Out:
# [{'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2000.0,
#   'value': '1.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2000.0,
#   'value': '0.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2000.0,
#   'value': '0.6',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2001.0,
#   'value': '0.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2001.0,
#   'value': '1.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2001.0,
#   'value': '0.6',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2002.0,
#   'value': '1.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2002.0,
#   'value': '0.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2002.0,
#   'value': '0.6',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2003.0,
#   'value': '0.6',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2003.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2003.0,
#   'value': '0.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2004.0,
#   'value': '0.5',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2004.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2004.0,
#   'value': '0.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2005.0,
#   'value': '0.4',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2005.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2005.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2006.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2006.0,
#   'value': '0.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2006.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2007.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2007.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2007.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2008.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2008.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2008.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2009.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2009.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2009.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2010.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2010.0,
#   'value': '0.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2010.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2011.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2011.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2011.0,
#   'value': '0.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2012.0,
#   'value': '0.4',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'E', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2012.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'E', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2012.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'E', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2013.0,
#   'value': '0.6',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2013.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2013.0,
#   'value': '0.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2014.0,
#   'value': '0.8',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2014.0,
#   'value': '0.4',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2014.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2015.0,
#   'value': '0.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2015.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2015.0,
#   'value': '0.5',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2016.0,
#   'value': '0.4',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2016.0,
#   'value': '0.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2016.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2017.0,
#   'value': '0.6',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2017.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2017.0,
#   'value': '0.4',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2018.0,
#   'value': '0.5',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2018.0,
#   'value': '0.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '8',
#   'geoAreaName': 'Albania',
#   'timePeriodStart': 2018.0,
#   'value': '0.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '12',
#   'geoAreaName': 'Algeria',
#   'timePeriodStart': 2000.0,
#   'value': '1.9',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '12',
#   'geoAreaName': 'Algeria',
#   'timePeriodStart': 2000.0,
#   'value': '1.5',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
# ...
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2004.0,
#   'value': '10.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2004.0,
#   'value': '10.0',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2004.0,
#   'value': '10.1',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2005.0,
#   'value': '8.8',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2005.0,
#   'value': '8.9',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2005.0,
#   'value': '8.8',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2006.0,
#   'value': '7.7',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2006.0,
#   'value': '7.8',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2006.0,
#   'value': '7.7',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2007.0,
#   'value': '6.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2007.0,
#   'value': '6.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2007.0,
#   'value': '6.3',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2008.0,
#   'value': '4.9',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2008.0,
#   'value': '4.9',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2008.0,
#   'value': '4.9',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2009.0,
#   'value': '4.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2009.0,
#   'value': '4.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'BOTHSEX', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2009.0,
#   'value': '4.2',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'MALE', 'Reporting Type': 'G'}},
#  {'goal': ['1'],
#   'target': ['1.1'],
#   'indicator': ['1.1.1'],
#   'series': 'SI_POV_EMP1',
#   'seriesDescription': 'Employed population below international poverty line, by sex and age (%)',
#   'seriesCount': '22878',
#   'geoAreaCode': '132',
#   'geoAreaName': 'Cabo Verde',
#   'timePeriodStart': 2010.0,
#   'value': '3.9',
#   'valueType': 'Float',
#   'time_detail': None,
#   'timeCoverage': None,
#   'upperBound': None,
#   'lowerBound': None,
#   'basePeriod': None,
#   'source': 'ILO modelled estimates, November 2020, available in ILOSTAT (https://ilostat.ilo.org/). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.',
#   'geoInfoUrl': None,
#   'footnotes': [''],
#   'attributes': {'Nature': 'M', 'Units': 'PERCENT'},
#   'dimensions': {'Age': '15+', 'Sex': 'FEMALE', 'Reporting Type': 'G'}},
#  ...]

# %%
data

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/ME2/preprocessed/ME2_origin.M.csv').query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GJ1/processed/GJ1_origin.M.csv')

# %%
test.query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GE1/processed/GE1.csv')

# %%
test.query("ISO == 'DEU'")
