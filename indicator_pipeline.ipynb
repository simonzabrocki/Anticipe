# %%
from tasks.download import download_indicator
from tasks.preprocess import preprocess_APIs_data_in_indicator, preprocess_MANUAL_data_in_indicator
from tasks.process import process_indicator

# %%
def indicator_pipeline(indicator, fresh_start=True):
    
    print(f'Downloading..')
    download_indicator(indicator, fresh_start)
    
    print('Preprocessing...')
    preprocess_MANUAL_data_in_indicator(indicator)
    preprocess_APIs_data_in_indicator(indicator)
    
    print('Processing...')
    process_indicator(indicator)

# %%
indicator_pipeline("ME1", fresh_start=False)
# Out:
# Downloading..
# Downloading ME1's data: ME1_SDG.json already there
# DONE
# Preprocessing...
# PreProcessing ME1 Manual files: Saving at data/indicator/ME1/preprocessed/ME1_origin.M.csv
# Done
# PreProcessing data/indicator/ME1/raw/ME1_SDG.json: Saving at data/indicator/ME1/preprocessed/ME1_SDG.csv
# Done
# Processing...
# Processing ME1:
# 	 Processing ME1_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/ME1/processed/ME1_origin.M.csv
# 	 Processing ME1_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/ME1/processed/ME1_SDG.csv

# %%
from tasks.compute_index import compute_index 
compute_index(save=True)
# Out:
# Computing Index:
# Collecting data:Saving at data/full_data/data.csv
# Computation: Saving 2005's results
# Saving 2006's results
# Saving 2007's results
# Saving 2008's results
# Saving 2009's results
# Saving 2010's results
# Saving 2011's results
# Saving 2012's results
# Saving 2013's results
# Saving 2014's results
# Saving 2015's results
# Saving 2016's results
# Saving 2017's results
# Saving 2018's results
# Saving 2019's results
# Saving 2020's results
# saving at data/full_data/result.csv

# %%
from tasks.post_process import make_timeseries_excel, make_imputation_report, make_data_report

make_timeseries_excel()
# Out:
# AB1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# AB2
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# AB3
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# BE1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# BE2
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# BE3
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# CV1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# CV2
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# CV3
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# EE1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# EE2
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# EQ1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# EQ2
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# EQ3
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# EW1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# EW2
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GB1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GB2
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GB3
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GE1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GE2
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GE3
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GJ1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GN1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GT1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GV1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# ME1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# ME2
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# SE1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# SE2
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# SE3
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# SL1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# SL2
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# SP1
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# SP2
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# SP3
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# AB
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# BE
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# CV
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# EE
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# EQ
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# EW
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GB
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GE
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GJ
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GN
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GT
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GV
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# ME
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# SE
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# SL
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# SP
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# SI
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# NCP
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# ESRU
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# GEO
# C:\Users\Innocent\Desktop\GGGI Project\Anticipe\11-08-2021\Anticipe\tasks\post_process.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_formatted['Year'] = df_formatted['Year'].astype(int)
# Index

# %%
make_imputation_report()

# %%
make_data_report()

# %%
#correlation 
from tasks.post_process import make_2019_2020_correlation_report

data, corr_by_var , corr_by_var_ISO = make_2019_2020_correlation_report()

# %%
data
# Out:
# version                               v_2019     v_2020
# Variable Aggregation      ISO Year
# AB       Category         AFG 2005.0    9.57   9.479588
#                               2006.0   12.00  11.647908
#                               2007.0   15.72  14.631056
#                               2008.0   21.40  18.201596
#                               2009.0   23.74  20.346813
# ...                                      ...        ...
# SP3      Indicator_normed ZWE 2016.0   70.69  70.693507
#                               2017.0   67.93  67.933955
#                               2018.0   65.24  65.235842
#                               2019.0   65.24  65.235842
#                               2020.0   65.24  65.235842
#
# [171772 rows x 2 columns]

# %%
corr_by_var.query('corr < 0.9')
# Out:
#    Variable       Aggregation      corr
# 47      GE1         Indicator  0.798867
# 48      GE1  Indicator_normed  0.770216
# 51      GE3         Indicator  0.898253
# 57       GN          Category  0.584670
# 58      GN1         Indicator  0.209781
# 59      GN1  Indicator_normed  0.584670
# 67       ME          Category  0.309106
# 68      ME1         Indicator -0.305315
# 69      ME1  Indicator_normed -0.298232
# 76      SE2         Indicator  0.438966
# 81       SL          Category  0.762107
# 83      SL1  Indicator_normed  0.695073
