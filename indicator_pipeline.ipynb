# %%
from tasks.pipeline import indicator_pipeline
from tasks.compute_indicators import compute_indicator
import pandas as pd

# %%
#compute_indicator('AB1')

# %%
indicator_pipeline("EE3", fresh_start=False)
# Out:
# Downloading..
# Downloading EE3's data: DONE
# Preprocessing...
# PreProcessing EE3 Manual files: Saving at data/indicator/EE3/preprocessed/EE3_origin.M.csv
# Done
# Processing...
# Processing EE3:
# 	 Processing EE3_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/EE3/processed/EE3_origin.M.csv

# %%
pd.read_csv('data/indicator/EE3/processed/EE3_origin.M.csv').dropna().query("ISO == 'FRA'")
# Out:
#       ISO  Year Indicator                          Description   Source  \
# 1107  FRA  2015       EE3  Efficiency in sustainable transport  sum4all
# 1108  FRA  2016       EE3  Efficiency in sustainable transport  sum4all
# 1109  FRA  2017       EE3  Efficiency in sustainable transport  sum4all
# 1110  FRA  2018       EE3  Efficiency in sustainable transport  sum4all
# 1111  FRA  2019       EE3  Efficiency in sustainable transport  sum4all
# 1112  FRA  2020       EE3  Efficiency in sustainable transport  sum4all
#
#                                                     URL    From  Imputed  \
# 1107  https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 1108  https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 1109  https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 1110  https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 1111  https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 1112  https://www.sum4all.org/gra-tool/country-perfo...  MANUAL    False
#
#           Value  Corrected Country
# 1107  92.152975      False  France
# 1108  92.152975      False  France
# 1109  92.152975      False  France
# 1110  92.152975      False  France
# 1111  92.152975      False  France
# 1112  92.152975      False  France

# %%
pd.read_csv('data/indicator/GJ2/processed/GJ2_origin.M.csv').dropna()

# %%
pd.read_csv('data/indicator/AB3/preprocessed/AB3_origin.M.csv')

# %%
pd.read_csv('data/indicator/ME3/preprocessed/ME3.1_SDG.csv')

# %%
pd.read_csv('data/indicator/AB1/preprocessed/AB1.3_SDG.csv').Description.unique()

# %%
import json

with open('data/indicator/GJ3/raw/GJ3_SDG.json') as json_file:
    data = json.load(json_file)

# %%
data['data']

# %%
data

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/ME2/preprocessed/ME2_origin.M.csv').query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GJ1/processed/GJ1_origin.M.csv')

# %%
test.query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GE1/processed/GE1.csv')

# %%
test.query("ISO == 'DEU'")
