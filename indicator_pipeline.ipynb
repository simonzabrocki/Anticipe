# %%
from tasks.download import download_indicator
from tasks.preprocess import preprocess_APIs_data_in_indicator, preprocess_MANUAL_data_in_indicator
from tasks.process import process_indicator
from tasks.compute_indicators import compute_indicator
import pandas as pd

# %%
def indicator_pipeline(indicator, fresh_start=True):
    
    print(f'Downloading..')
    download_indicator(indicator, fresh_start)
    
    print('Preprocessing...')
    preprocess_MANUAL_data_in_indicator(indicator)
    preprocess_APIs_data_in_indicator(indicator)
    
    print('Processing...')
    process_indicator(indicator)

# %%
#compute_indicator('AB1')
# Out:
# Computing AB1 for AB1_SDG.csv: DONE

# %%
indicator_pipeline("AB1", fresh_start=False)
# Out:
# Downloading..
# Downloading AB1's data: AB1.0_SDG.json already there
# AB1.1_SDG.json already there
# AB1.2_SDG.json already there
# AB1.3_SDG.json already there
# DONE
# Preprocessing...
# PreProcessing AB1 Manual files: Error:  'NoneType' object is not subscriptable
# PreProcessing data/indicator/AB1/raw/AB1.3_SDG.json: Saving at data/indicator/AB1/preprocessed/AB1.3_SDG.csv
# Done
# PreProcessing data/indicator/AB1/raw/AB1.1_SDG.json: Saving at data/indicator/AB1/preprocessed/AB1.1_SDG.csv
# Done
# PreProcessing data/indicator/AB1/raw/AB1.2_SDG.json: Saving at data/indicator/AB1/preprocessed/AB1.2_SDG.csv
# Done
# PreProcessing data/indicator/AB1/raw/AB1.0_SDG.json: Saving at data/indicator/AB1/preprocessed/AB1.0_SDG.csv
# Done
# Processing...
# Processing AB1:
# 	 Processing sub indicators from AB1.0_SDG.csv, AB1.1_SDG.csv, AB1.2_SDG.csv, AB1.3_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 Computing AB1 for AB1_SDG.csv: DONE
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# saving at data/indicator/AB1/processed/AB1_SDG.csv

# %%
pd.read_csv('data/indicator/AB1/processed/AB1_SDG.csv')
# Out:
#       ISO  Year                                        Description Indicator  \
# 0     ABW  2000  [ (Proportion of population using safely manag...       AB1
# 1     ABW  2001  [ (Proportion of population using safely manag...       AB1
# 2     ABW  2002  [ (Proportion of population using safely manag...       AB1
# 3     ABW  2003  [ (Proportion of population using safely manag...       AB1
# 4     ABW  2004  [ (Proportion of population using safely manag...       AB1
# ...   ...   ...                                                ...       ...
# 4762  ZWE  2016  [ (Proportion of population using safely manag...       AB1
# 4763  ZWE  2017  [ (Proportion of population using safely manag...       AB1
# 4764  ZWE  2018  [ (Proportion of population using safely manag...       AB1
# 4765  ZWE  2019  [ (Proportion of population using safely manag...       AB1
# 4766  ZWE  2020  [ (Proportion of population using safely manag...       AB1
#
#          From                                             Source  \
# 0     SDG API  WHO/UNICEF Joint Monitoring Programme for Wate...
# 1     SDG API  WHO/UNICEF Joint Monitoring Programme for Wate...
# 2     SDG API  WHO/UNICEF Joint Monitoring Programme for Wate...
# 3     SDG API  WHO/UNICEF Joint Monitoring Programme for Wate...
# 4     SDG API  WHO/UNICEF Joint Monitoring Programme for Wate...
# ...       ...                                                ...
# 4762  SDG API  WHO/UNICEF Joint Monitoring Programme for Wate...
# 4763  SDG API  WHO/UNICEF Joint Monitoring Programme for Wate...
# 4764  SDG API  WHO/UNICEF Joint Monitoring Programme for Wate...
# 4765  SDG API  WHO/UNICEF Joint Monitoring Programme for Wate...
# 4766  SDG API  WHO/UNICEF Joint Monitoring Programme for Wate...
#
#                                                     URL  Imputed   Value  \
# 0     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...    False  100.00
# 1     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...    False  100.00
# 2     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...    False  100.00
# 3     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...    False  100.00
# 4     https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...    False  100.00
# ...                                                 ...      ...     ...
# 4762  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...    False   31.75
# 4763  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...    False   31.75
# 4764  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...    False   31.75
# 4765  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...    False   31.75
# 4766  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...    False   31.75
#
#       Corrected   Country
# 0         False     Aruba
# 1         False     Aruba
# 2         False     Aruba
# 3         False     Aruba
# 4         False     Aruba
# ...         ...       ...
# 4762      False  Zimbabwe
# 4763      False  Zimbabwe
# 4764      False  Zimbabwe
# 4765      False  Zimbabwe
# 4766      False  Zimbabwe
#
# [4767 rows x 11 columns]

# %%
pd.read_csv('data/indicator/AB1/preprocessed/AB1.3_SDG.csv').Description.unique()

# %%
import json

with open('data/indicator/GJ3/raw/GJ3_SDG.json') as json_file:
    data = json.load(json_file)

# %%
data['data']

# %%
data

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/ME2/preprocessed/ME2_origin.M.csv').query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GJ1/processed/GJ1_origin.M.csv')

# %%
test.query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GE1/processed/GE1.csv')

# %%
test.query("ISO == 'DEU'")
