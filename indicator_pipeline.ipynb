# %%
from tasks.pipeline import indicator_pipeline
from tasks.compute_indicators import compute_indicator
import pandas as pd

# %%
#compute_indicator('AB1')

# %%
from processing.utils import add_ISO


def get_loss_prod():
    df = (
        pd.read_csv('data/indicator/ME3/raw/ME3.1_FAO.M.csv')
          .groupby(['Area', 'Year', 'Element'])['Value'].sum().reset_index()
          .pivot(index=['Area', 'Year'], columns='Element', values='Value')
    )
    
    df['Value'] = df['Loss'] / df['Production'] * 100
    df = df['Value'].reset_index().rename(columns={'Area': 'Country'})
    df = add_ISO(df)
    return df

# def get_waste_cons():
    
#     cons = (
#     pd.read_csv('data/indicator/ME3/raw/ME3.2_FAO.M.csv')
#       .groupby(['Area', 'Year', 'Element'])['Value'].sum().reset_index()

# )

# %%
get_loss_prod()
# Out:
#          Country  ISO  Year     Value
# 0    Afghanistan  AFG  2014  7.173259
# 1    Afghanistan  AFG  2015  6.810589
# 2    Afghanistan  AFG  2016  7.301008
# 3    Afghanistan  AFG  2017  6.726861
# 4    Afghanistan  AFG  2018  6.114663
# ..           ...  ...   ...       ...
# 870     Zimbabwe  ZWE  2014  3.866814
# 871     Zimbabwe  ZWE  2015  4.149432
# 872     Zimbabwe  ZWE  2016  4.217453
# 873     Zimbabwe  ZWE  2017  5.564645
# 874     Zimbabwe  ZWE  2018  4.297875
#
# [870 rows x 4 columns]

# %%
indicator_pipeline("ME3", fresh_start=False)
# Out:
# Downloading..
# Downloading ME3's data: Downloading {'GGI_code': 'ME3.0', 'params': {'seriesCode': 'AG_FOOD_WST'}} from SDG: DONE
# Saving at data/indicator/ME3/raw/ME3.0_SDG.json: DONE
# DONE
# Preprocessing...
# PreProcessing ME3 Manual files: Saving at data/indicator/ME3/preprocessed/ME3.1_origin.M.csv
# Done
# PreProcessing data/indicator/ME3/raw/ME3.0_SDG.json: Saving at data/indicator/ME3/preprocessed/ME3.0_SDG.csv
# Done
# Processing...
# Processing ME3:
# 	 Processing ME3.1_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/ME3/processed/ME3.1_origin.M.csv
# 	 Processing ME3.0_SDG.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/ME3/processed/ME3.0_SDG.csv

# %%
from tasks.post_process import get_info_from_indictor_df

# %%
pd.read_csv('data/indicator/ME3/preprocessed/ME3.1_origin.M.csv')
# Out:
#      ISO  Year     Value Variable  \
# 0    AFG  2014  7.173259    ME3.1
# 1    AFG  2015  6.810589    ME3.1
# 2    AFG  2016  7.301008    ME3.1
# 3    AFG  2017  6.726861    ME3.1
# 4    AFG  2018  6.114663    ME3.1
# ..   ...   ...       ...      ...
# 860  ZWE  2014  3.866814    ME3.1
# 861  ZWE  2015  4.149432    ME3.1
# 862  ZWE  2016  4.217453    ME3.1
# 863  ZWE  2017  5.564645    ME3.1
# 864  ZWE  2018  4.297875    ME3.1
#
#                                            Description Source  \
# 0    Share food loss to total food production (Perc...    FAO
# 1    Share food loss to total food production (Perc...    FAO
# 2    Share food loss to total food production (Perc...    FAO
# 3    Share food loss to total food production (Perc...    FAO
# 4    Share food loss to total food production (Perc...    FAO
# ..                                                 ...    ...
# 860  Share food loss to total food production (Perc...    FAO
# 861  Share food loss to total food production (Perc...    FAO
# 862  Share food loss to total food production (Perc...    FAO
# 863  Share food loss to total food production (Perc...    FAO
# 864  Share food loss to total food production (Perc...    FAO
#
#                                          URL    From
# 0    http://www.fao.org/faostat/en/#data/SCL  MANUAL
# 1    http://www.fao.org/faostat/en/#data/SCL  MANUAL
# 2    http://www.fao.org/faostat/en/#data/SCL  MANUAL
# 3    http://www.fao.org/faostat/en/#data/SCL  MANUAL
# 4    http://www.fao.org/faostat/en/#data/SCL  MANUAL
# ..                                       ...     ...
# 860  http://www.fao.org/faostat/en/#data/SCL  MANUAL
# 861  http://www.fao.org/faostat/en/#data/SCL  MANUAL
# 862  http://www.fao.org/faostat/en/#data/SCL  MANUAL
# 863  http://www.fao.org/faostat/en/#data/SCL  MANUAL
# 864  http://www.fao.org/faostat/en/#data/SCL  MANUAL
#
# [865 rows x 8 columns]

# %%
pd.read_csv('data/indicator/ME3/preprocessed/ME3.0_SDG.csv')
# Out:
#          Country  ISO                                        Description  \
# 0    Afghanistan  AFG  Food waste (Tonnes) Reporting Type G Food Wast...
# 1    Afghanistan  AFG  Food waste (Tonnes) Reporting Type G Food Wast...
# 2    Afghanistan  AFG  Food waste (Tonnes) Reporting Type G Food Wast...
# 3        Albania  ALB  Food waste (Tonnes) Reporting Type G Food Wast...
# 4        Albania  ALB  Food waste (Tonnes) Reporting Type G Food Wast...
# ..           ...  ...                                                ...
# 640       Zambia  ZMB  Food waste (Tonnes) Reporting Type G Food Wast...
# 641       Zambia  ZMB  Food waste (Tonnes) Reporting Type G Food Wast...
# 642     Zimbabwe  ZWE  Food waste (Tonnes) Reporting Type G Food Wast...
# 643     Zimbabwe  ZWE  Food waste (Tonnes) Reporting Type G Food Wast...
# 644     Zimbabwe  ZWE  Food waste (Tonnes) Reporting Type G Food Wast...
#
#                                   Source  Year         Value  \
# 0    Food Waste Index Report 2021 / WESR  2019  3.109153e+06
# 1    Food Waste Index Report 2021 / WESR  2019  1.051783e+06
# 2    Food Waste Index Report 2021 / WESR  2019  5.949824e+05
# 3    Food Waste Index Report 2021 / WESR  2019  2.384918e+05
# 4    Food Waste Index Report 2021 / WESR  2019  7.965134e+04
# ..                                   ...   ...           ...
# 640  Food Waste Index Report 2021 / WESR  2019  1.391729e+06
# 641  Food Waste Index Report 2021 / WESR  2019  2.793501e+05
# 642  Food Waste Index Report 2021 / WESR  2019  1.458564e+06
# 643  Food Waste Index Report 2021 / WESR  2019  4.049199e+05
# 644  Food Waste Index Report 2021 / WESR  2019  2.290590e+05
#
#                                                    URL DownloadDate Variable  \
# 0    https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19    ME3.0
# 1    https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19    ME3.0
# 2    https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19    ME3.0
# 3    https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19    ME3.0
# 4    https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19    ME3.0
# ..                                                 ...          ...      ...
# 640  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19    ME3.0
# 641  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19    ME3.0
# 642  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19    ME3.0
# 643  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19    ME3.0
# 644  https://unstats.un.org/SDGAPI/v1/sdg/Series/Da...   2021-08-19    ME3.0
#
#         From
# 0    SDG API
# 1    SDG API
# 2    SDG API
# 3    SDG API
# 4    SDG API
# ..       ...
# 640  SDG API
# 641  SDG API
# 642  SDG API
# 643  SDG API
# 644  SDG API
#
# [645 rows x 10 columns]

# %%
df_list = [
    pd.read_csv('data/indicator/ME2/processed/ME2.0_origin.M.csv'),
    pd.read_csv('data/indicator/ME2/processed/ME2.1_SDG.csv'),
    pd.read_csv('data/indicator/ME2/processed/ME2.2_SDG.csv')
]

pd.concat([get_info_from_indictor_df(df) for df in df_list])

# %%
pd.read_csv('data/indicator/ME2/processed/ME')

# %%
indicator_pipeline("SL3", fresh_start=False)

# %%
pd.read_csv('data/indicator/EE3/processed/EE3_origin.M.csv').dropna().query("ISO == 'FRA'")

# %%
pd.read_csv('data/indicator/GJ2/processed/GJ2_origin.M.csv').dropna()

# %%
pd.read_csv('data/indicator/AB3/preprocessed/AB3_origin.M.csv')

# %%
pd.read_csv('data/indicator/ME3/preprocessed/ME3.1_SDG.csv')

# %%
pd.read_csv('data/indicator/AB1/preprocessed/AB1.3_SDG.csv').Description.unique()

# %%
import json

with open('data/indicator/GJ3/raw/GJ3_SDG.json') as json_file:
    data = json.load(json_file)

# %%
data['data']

# %%
data

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/ME2/preprocessed/ME2_origin.M.csv').query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GJ1/processed/GJ1_origin.M.csv')

# %%
test.query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GE1/processed/GE1.csv')

# %%
test.query("ISO == 'DEU'")
