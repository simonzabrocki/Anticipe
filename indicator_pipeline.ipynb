# %%
from tasks.download import download_indicator
from tasks.preprocess import preprocess_APIs_data_in_indicator, preprocess_MANUAL_data_in_indicator
from tasks.process import process_indicator
from tasks.compute_indicators import compute_indicator
import pandas as pd

# %%
def indicator_pipeline(indicator, fresh_start=True):
    
    print(f'Downloading..')
    download_indicator(indicator, fresh_start)
    
    print('Preprocessing...')
    preprocess_MANUAL_data_in_indicator(indicator)
    preprocess_APIs_data_in_indicator(indicator)
    
    print('Processing...')
    process_indicator(indicator)

# %%
#compute_indicator('AB1')

# %%
indicator_pipeline("AB3", fresh_start=False)
# Out:
# Downloading..
# Downloading AB3's data: DONE
# Preprocessing...
# PreProcessing AB3 Manual files: Saving at data/indicator/AB3/preprocessed/AB3_origin.M.csv
# Done
# PreProcessing data/indicator/AB3/raw/Rapid Transit to Resident Ratio.csv: Error:  Expecting value: line 1 column 1 (char 0)
# PreProcessing data/indicator/AB3/raw/Logistics performance index.csv: Error:  Expecting value: line 1 column 1 (char 0)
# PreProcessing data/indicator/AB3/raw/Percentage of female workers in transport.csv: Error:  Expecting value: line 1 column 1 (char 0)
# PreProcessing data/indicator/AB3/raw/Rural access index.csv: Error:  Expecting value: line 1 column 1 (char 0)
# Processing...
# Processing AB3:
# 	 Processing AB3_origin.M.csv
# 	 Imputation:DONE
# 	 Outlier removal:DONE
# 	 Formatting:DONE
# 	 saving at data/indicator/AB3/processed/AB3_origin.M.csv

# %%
pd.read_csv('data/indicator/AB3/processed/AB3_origin.M.csv')#.dropna()
# Out:
#       ISO  Year Indicator                               Description   Source  \
# 0     AFG  2000       AB3  Universal access - sustainable transport  sum4all
# 1     AFG  2001       AB3  Universal access - sustainable transport  sum4all
# 2     AFG  2002       AB3  Universal access - sustainable transport  sum4all
# 3     AFG  2003       AB3  Universal access - sustainable transport  sum4all
# 4     AFG  2004       AB3  Universal access - sustainable transport  sum4all
# ...   ...   ...       ...                                       ...      ...
# 2179  ZWE  2016       AB3  Universal access - sustainable transport  sum4all
# 2180  ZWE  2017       AB3  Universal access - sustainable transport  sum4all
# 2181  ZWE  2018       AB3  Universal access - sustainable transport  sum4all
# 2182  ZWE  2019       AB3  Universal access - sustainable transport  sum4all
# 2183  ZWE  2020       AB3  Universal access - sustainable transport  sum4all
#
#                                                     URL    From  Imputed  \
# 0     https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 1     https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 2     https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 3     https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 4     https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# ...                                                 ...     ...      ...
# 2179  https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 2180  https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 2181  https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 2182  https://www.sum4all.org/gra-tool/country-perfo...  MANUAL     True
# 2183  https://www.sum4all.org/gra-tool/country-perfo...  MANUAL    False
#
#           Value  Corrected      Country
# 0           NaN      False  Afghanistan
# 1           NaN      False  Afghanistan
# 2           NaN      False  Afghanistan
# 3           NaN      False  Afghanistan
# 4           NaN      False  Afghanistan
# ...         ...        ...          ...
# 2179  26.503879      False     Zimbabwe
# 2180  26.503879      False     Zimbabwe
# 2181  26.503879      False     Zimbabwe
# 2182  26.503879      False     Zimbabwe
# 2183  26.503879      False     Zimbabwe
#
# [2184 rows x 11 columns]

# %%
pd.read_csv('data/indicator/AB1/preprocessed/AB1.3_SDG.csv').Description.unique()

# %%
import json

with open('data/indicator/GJ3/raw/GJ3_SDG.json') as json_file:
    data = json.load(json_file)

# %%
data['data']

# %%
data

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/EW3/processed/EW3_SDG.csv')

# %%
pd.read_csv('data/indicator/ME2/preprocessed/ME2_origin.M.csv').query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GJ1/processed/GJ1_origin.M.csv')

# %%
test.query("ISO == 'FRA'")

# %%
import pandas as pd
test = pd.read_csv('data/indicator/GE1/processed/GE1.csv')

# %%
test.query("ISO == 'DEU'")
